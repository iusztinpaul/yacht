# %%
import yfinance
import mplfinance as mpf
import matplotlib. pyplot as plt
import numpy as np

# %% [markdown]
# # Define Constants

# %%
TICKERS = ['PLUG']
START = '2020-11-01'
END = None
INTERVAL = '1d'

# %% [markdown]
# # Live Data Availability

# %%
data = yfinance.download(
            tickers=TICKERS,
            start=START,
            end=END,
            interval=INTERVAL,
            auto_adjust=False,
            prepost=False
        )
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data.tail()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2021-10-19  32.759998  33.509998  31.910000  33.439999  33.439999  24613000
# 2021-10-20  33.450001  33.810001  32.529999  32.919998  32.919998  19283600
# 2021-10-21  32.959999  34.959999  32.860001  33.669998  33.669998  27680100
# 2021-10-22  33.560001  33.599998  31.959999  32.700001  32.700001  16418500
# 2021-10-25  33.137199  34.419998  32.910000  34.334999  34.334999  14720615

# %% [markdown]
# We can see that we have data even during the current date.

# %% [markdown]
# # Download Data

# %%
tickers_data_unadjusted = yfinance.download(
            tickers=TICKERS,
            start=START,
            end=END,
            interval=INTERVAL,
            auto_adjust=False,
            prepost=False
        )
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
tickers_data_unadjusted.head()
# Out:
#                  Open       High    Low      Close  Adj Close    Volume
# Date
# 2020-11-02  14.400000  15.500000  13.92  15.470000  15.470000  32024300
# 2020-11-03  16.129999  17.400000  15.87  16.950001  16.950001  56500800
# 2020-11-04  16.330000  16.760000  15.25  16.610001  16.610001  38066500
# 2020-11-05  17.650000  18.879999  17.59  18.840000  18.840000  39553100
# 2020-11-06  18.500000  19.100000  17.76  18.860001  18.860001  31738900

# %%
tickers_data = yfinance.download(
            tickers=TICKERS,
            start=START,
            end=END,
            interval=INTERVAL,
            auto_adjust=True,
            prepost=False
        )
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
print(len(tickers_data))
tickers_data.head()
# Out:
# 247
#                  Open       High    Low      Close    Volume
# Date
# 2020-11-02  14.400000  15.500000  13.92  15.470000  32024300
# 2020-11-03  16.129999  17.400000  15.87  16.950001  56500800
# 2020-11-04  16.330000  16.760000  15.25  16.610001  38066500
# 2020-11-05  17.650000  18.879999  17.59  18.840000  39553100
# 2020-11-06  18.500000  19.100000  17.76  18.860001  31738900

# %%
tickers_data_with_actions = yfinance.download(
            tickers=TICKERS,
            start=START,
            end=END,
            interval=INTERVAL,
            auto_adjust=True,
            prepost=False,
            actions=True
        )
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
print(len(tickers_data_with_actions))
tickers_data.head(n=40)
# Out:
# 247
#                  Open       High        Low      Close    Volume
# Date
# 2020-11-02  14.400000  15.500000  13.920000  15.470000  32024300
# 2020-11-03  16.129999  17.400000  15.870000  16.950001  56500800
# 2020-11-04  16.330000  16.760000  15.250000  16.610001  38066500
# 2020-11-05  17.650000  18.879999  17.590000  18.840000  39553100
# 2020-11-06  18.500000  19.100000  17.760000  18.860001  31738900
# 2020-11-09  19.450001  21.889999  18.469999  20.309999  56114000
# 2020-11-10  21.190001  21.610001  19.030001  20.010000  39513500
# 2020-11-11  20.340000  23.000000  20.340000  23.000000  59408100
# 2020-11-12  22.850000  24.260000  21.930000  23.450001  53484400
# 2020-11-13  24.350000  24.780001  22.240000  23.430000  45987100
# 2020-11-16  23.650000  25.490000  23.620001  25.000000  46065400
# 2020-11-17  22.059999  23.379999  22.000000  22.980000  78945900
# 2020-11-18  23.370001  23.799999  22.559999  23.219999  34965000
# 2020-11-19  23.670000  24.870001  23.450001  23.790001  44568000
# 2020-11-20  24.100000  24.740000  23.969999  24.360001  24135400
# 2020-11-23  24.950001  27.020000  24.740000  26.870001  45700300
# 2020-11-24  28.360001  28.700001  25.510000  26.719999  51677900
# 2020-11-25  25.799999  26.400000  25.070000  26.160000  30996200
# 2020-11-27  26.990000  27.780001  25.660000  26.240000  23115600
# 2020-11-30  27.330000  27.350000  23.510000  26.389999  33651300
# 2020-12-01  25.920000  26.049999  23.750000  24.469999  32473600
# 2020-12-02  22.629999  24.799999  22.250000  24.070000  30650200
# 2020-12-03  24.340000  24.730000  23.809999  23.850000  17686700
# 2020-12-04  24.270000  24.930000  23.950001  24.850000  18433700
# 2020-12-07  25.400000  25.980000  24.440001  24.750000  16997600
# 2020-12-08  25.010000  29.490000  24.920000  28.740000  69823100
# 2020-12-09  28.799999  29.690001  26.170000  26.740000  36201300
# 2020-12-10  26.500000  28.110001  26.260000  27.190001  24464800
# 2020-12-11  27.080000  27.850000  26.219999  26.770000  16732500
# 2020-12-14  27.190001  27.400000  25.700001  25.700001  16546400
# 2020-12-15  27.389999  29.309999  26.860001  28.469999  49624400
# 2020-12-16  28.549999  28.770000  27.400000  28.459999  22609100
# 2020-12-17  28.500000  30.980000  28.490000  30.570000  42578400
# 2020-12-18  30.530001  33.020000  29.879999  31.629999  52665500
# 2020-12-21  31.420000  32.459999  30.459999  32.369999  35161300
# 2020-12-22  34.410000  36.740002  33.799999  35.689999  51652500
# 2020-12-23  36.759998  37.110001  34.680000  36.139999  40179900
# 2020-12-24  35.709999  36.669998  34.750000  35.580002  19919300
# 2020-12-28  37.369999  37.509998  33.529999  33.570000  35787800
# 2020-12-29  33.330002  33.459999  30.840000  32.459999  32063600

# %% [markdown]
# # Data Continuity

# %%
mpf.plot(tickers_data.loc['2020-01-01':'2020-02-01'], type='candle')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_9221/328683506.py in <module>
# ----> 1 mpf.plot(tickers_data.loc['2020-01-01':'2020-02-01'], type='candle')
#
# ~/anaconda3/envs/yacht/lib/python3.8/site-packages/mplfinance/plotting.py in plot(data, **kwargs)
#     368         volumeAxes = panels.at[config['volume_panel'],'axes'][0] if config['volume'] is True else None
#     369
# --> 370     fmtstring = _determine_format_string(dates, config['datetime_format'])
#     371
#     372     ptype = config['type']
#
# ~/anaconda3/envs/yacht/lib/python3.8/site-packages/mplfinance/_helpers.py in _determine_format_string(dates, datetime_format)
#      41     datetime_format, use that as an override.
#      42     """
# ---> 43     avg_days_between_points = (dates[-1] - dates[0]) / float(len(dates))
#      44
#      45     if datetime_format is not None:
#
# IndexError: index -1 is out of bounds for axis 0 with size 0

# %% [markdown]
# We can see that there is noise between weekends or other holidays when the market is not open.

# %% [markdown]
# # Stock Splits Continuity

# %% [markdown]
# A stock split was made on the APPL stock on 31 August 2021. Lets see if the data is readjusted to the split.

# %%
tickers_data_with_actions.loc['2020-08-20':'2020-9-10']

# %%
mpf.plot(tickers_data_with_actions.loc['2020-07-01':'2020-10-01'], type='candle')

# %% [markdown]
# We can see that prices are adjusted to stock splits.

# %% [markdown]
# # Log Difference

# %%
tickers_data_values = tickers_data.values
tickers_data_values = np.log(tickers_data_values)
print(f'Shape: {tickers_data_values.shape}')
print(f'Min: {tickers_data_values.min()}')
print(f'Max: {tickers_data_values.max()}')

# %%
tickers_data_diff = np.diff(tickers_data_values, axis=0, prepend=tickers_data_values[0, :].reshape(1, -1))
print(f'Shape: {tickers_data_diff.shape}')
print(f'Min: {tickers_data_diff.min()}')
print(f'Max: {tickers_data_diff.max()}')

# %%
tickers_data_diff[0]

# %%
tickers_data_diff[1]

# %%
tickers_data_diff[-1]

# %%
# plot open prices
plt.plot(tickers_data_diff[:, 0])

# %%
# plot high prices
plt.plot(tickers_data_diff[:, 1])

# %%
# plot low prices
plt.plot(tickers_data_diff[:, 2])

# %%
# plot closing prices
plt.plot(tickers_data_diff[:, 3])

# %%
# plot volume 
plt.plot(tickers_data_diff[:, 4])
