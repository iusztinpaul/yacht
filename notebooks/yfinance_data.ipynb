# 2020-02-21  78.790226  79.242763  76.782266  77.412842  129554000
# 2020-02-24  73.508204  75.219418  71.522498  73.735703  222195200
# 2020-02-25  74.420681  74.811389  70.755903  71.238106  230673600
# 2020-02-26  70.854821  73.661518  70.847403  72.368210  198054800
# 2020-02-27  69.512058  70.723757  67.499147  67.637627  320605600

# %% [markdown]
# # Data Continuity

# %%
mpf.plot(tickers_data.loc['2020-01-01':'2020-02-01'], type='candle')

# %% [markdown]
# We can see that there is noise between weekends or other holidays when the market is not open.

# %% [markdown]
# # Stock Splits Continuity

# %% [markdown]
# A stock split was made on the APPL stock on 31 August 2021. Lets see if the data is readjusted to the split.

# %%
tickers_data_with_actions.loc['2020-08-20':'2020-9-10']
# Out:
#                   Open        High         Low       Close     Volume  \
# Date
# 2020-08-20  115.010270  117.635884  114.992880  117.519135  126907200
# 2020-08-21  118.500323  124.069506  118.487905  123.575188  338054800
# 2020-08-24  127.875024  127.961973  123.145449  125.053177  345937600
# 2020-08-25  123.900603  124.380017  122.266111  124.027283  211495600
# 2020-08-26  125.373618  126.180926  124.283128  125.713928  163022400
# 2020-08-27  126.329969  126.670279  123.041117  124.211098  155552400
# 2020-08-28  125.207189  125.634441  123.781362  124.009895  187630000
# 2020-08-31  126.764686  130.162828  125.194781  128.215347  225702700
# 2020-09-01  131.911586  133.938558  129.695841  133.322510  151948100
# 2020-09-02  136.710701  137.098208  126.188382  130.560257  200119000
# 2020-09-03  126.098953  128.016612  119.729914  120.107483  257599600
# 2020-09-04  119.302662  122.909461  110.181329  120.186974  332607200
# 2020-09-08  113.221782  118.229575  111.959902  112.099007  231366600
# 2020-09-09  116.510630  118.378612  114.523411  116.570244  176940500
# 2020-09-10  119.590816  119.729920  111.781046  112.764717  182274400
#
#             Dividends  Stock Splits
# Date
# 2020-08-20        0.0           0.0
# 2020-08-21        0.0           0.0
# 2020-08-24        0.0           0.0
# 2020-08-25        0.0           0.0
# 2020-08-26        0.0           0.0
# 2020-08-27        0.0           0.0
# 2020-08-28        0.0           0.0
# 2020-08-31        0.0           4.0
# 2020-09-01        0.0           0.0
# 2020-09-02        0.0           0.0
# 2020-09-03        0.0           0.0
# 2020-09-04        0.0           0.0
# 2020-09-08        0.0           0.0
# 2020-09-09        0.0           0.0
# 2020-09-10        0.0           0.0

# %%
mpf.plot(tickers_data_with_actions.loc['2020-07-01':'2020-10-01'], type='candle')

# %% [markdown]
# We can see that prices are adjusted to stock splits.

# %% [markdown]
# # Log Difference

# %%
tickers_data_values = tickers_data.values
tickers_data_values = np.log(tickers_data_values)
print(f'Shape: {tickers_data_values.shape}')
print(f'Min: {tickers_data_values.min()}')
print(f'Max: {tickers_data_values.max()}')
# Out:
# Shape: (448, 5)
# Min: 3.9622492376325
# Max: 19.87114637127999

# %%
tickers_data_diff = np.diff(tickers_data_values, axis=0, prepend=tickers_data_values[0, :].reshape(1, -1))
print(f'Shape: {tickers_data_diff.shape}')
print(f'Min: {tickers_data_diff.min()}')
print(f'Max: {tickers_data_diff.max()}')
# Out:
# Shape: (448, 5)
# Min: -0.7407797823044646
# Max: 1.2887651411035357

# %%
tickers_data_diff[0]
# Out:
# array([0., 0., 0., 0., 0.])

# %%
tickers_data_diff[1]
# Out:
# array([0.02153038, 0.02328975, 0.01939485, 0.02255989, 0.29563307])

# %%
tickers_data_diff[-1]
# Out:
# array([ 0.0067575 , -0.00027745, -0.00112173, -0.00272546, -0.05005553])

# %%
# plot open prices
plt.plot(tickers_data_diff[:, 0])

# %%
# plot high prices
plt.plot(tickers_data_diff[:, 1])

# %%
# plot low prices
plt.plot(tickers_data_diff[:, 2])

# %%
# plot closing prices
plt.plot(tickers_data_diff[:, 3])

# %%
# plot volume 
plt.plot(tickers_data_diff[:, 4])
